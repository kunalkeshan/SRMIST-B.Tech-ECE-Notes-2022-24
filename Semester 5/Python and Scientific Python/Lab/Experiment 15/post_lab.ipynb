# %%
import numpy as np
import pylab

tou=0.2
v=250
fsamp=1000
t=np.arange(0,1,1/fsamp)
n=len(l)
f=np.cos(2*np.pi*v*t)*np.exp(-t/tou)
f += 0.2*np.random.randn(n)
pylab.plot(t,f)
pylab.xlabel('Time /s')
# Out:
# Text(0.5, 0, 'Time /s')
